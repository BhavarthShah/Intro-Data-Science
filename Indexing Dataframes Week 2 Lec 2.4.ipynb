# %% [markdown]
# # Indexing Dataframes
# Week 2 Lec 2.4

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datasets/Admission_Predict.csv", index_col=0)

# %%
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
#now we want to create an index of 'CHANGE OF ADMIT' instead of Serial , hence we use
# .set_index() func

# %%
df = df.set_index['Change of Admit']

#error because we used [] instead of () for the method
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-b1ba4bec65bf> in <module>
# ----> 1 df = df.set_index['Change of Admit']
#       2
#       3 #error because we used [] instead of () for the method
#
# TypeError: 'method' object is not subscriptable

# %%
df = df.set_index('Change of Admit')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-0625dfd4db5b> in <module>
# ----> 1 df = df.set_index('Change of Admit')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Change of Admit'] are in the columns"

# %%
#key error why? lets find out

df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
#ooh there is space after Admit making trouble -- we use list here

cols = list(df.columns)

cols = [x.upper().strip() for x in cols]

df.columns = cols

# %%
df.columns
# Out:
# Index(['GRE SCORE', 'TOEFL SCORE', 'UNIVERSITY RATING', 'SOP', 'LOR', 'CGPA',
#        'RESEARCH', 'CHANCE OF ADMIT'],
#       dtype='object')

# %%
#REMOVed the space here so now will work

df = df.set_index('CHANCE OF ADMIT')

# %%
df
# Out:
#                  GRE SCORE  TOEFL SCORE  UNIVERSITY RATING  SOP  LOR  CGPA  \
# CHANCE OF ADMIT
# 0.92                   337          118                  4  4.5  4.5  9.65
# 0.76                   324          107                  4  4.0  4.5  8.87
# 0.72                   316          104                  3  3.0  3.5  8.00
# 0.80                   322          110                  3  3.5  2.5  8.67
# 0.65                   314          103                  2  2.0  3.0  8.21
# ...                    ...          ...                ...  ...  ...   ...
# 0.82                   324          110                  3  3.5  3.5  9.04
# 0.84                   325          107                  3  3.0  3.5  9.11
# 0.91                   330          116                  4  5.0  4.5  9.45
# 0.67                   312          103                  3  3.5  4.0  8.78
# 0.95                   333          117                  4  5.0  4.0  9.66
#
#                  RESEARCH
# CHANCE OF ADMIT
# ...

# %%
#to reset the columns we use .reset_index() func

df = df.reset_index()

# %%
df.head()
# Out:
#    CHANCE OF ADMIT  GRE SCORE  TOEFL SCORE  UNIVERSITY RATING  SOP  LOR  CGPA  \
# 0             0.92        337          118                  4  4.5  4.5  9.65
# 1             0.76        324          107                  4  4.0  4.5  8.87
# 2             0.72        316          104                  3  3.0  3.5  8.00
# 3             0.80        322          110                  3  3.5  2.5  8.67
# 4             0.65        314          103                  2  2.0  3.0  8.21
#
#    RESEARCH
# 0         1
# 1         1
# 2         1
# 3         1
# 4         0

# %%
#now we need to reimport for MULTI pupose indexing

df = pd.read_csv("datasets/Admission_Predict.csv", index_col = 0)

# %%
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
df = df.set_index((df['GRE Score'].gt(315)), (df['TOEFL Score'].gt(105)))

# %%
df.head()
# Out:
#            GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# GRE Score
# True             337          118                  4  4.5   4.5  9.65
# True             324          107                  4  4.0   4.5  8.87
# True             316          104                  3  3.0   3.5  8.00
# True             322          110                  3  3.5   2.5  8.67
# False            314          103                  2  2.0   3.0  8.21
#
#            Research  Chance of Admit
# GRE Score
# True              1              0.92
# True              1              0.76
# True              1              0.72
# True              1              0.80
# False             0              0.65

# %%
# for tuples or other approaches uses .loc () attribute to query the data
